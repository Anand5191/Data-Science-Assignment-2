# %%
# Q1

"""The Probability Mass Function (PMF) is a function that gives the probability of each possible value of a discrete random variable.

The Probability Density Function (PDF) is used for continuous random variables and describes the likelihood of a random variable taking on a particular value.
Unlike the PMF, which assigns probabilities to specific outcomes, the PDF provides a density function ""

1. Probability Mass Function (PMF)
The PMF is used for discrete random variables (those that take specific values). It gives the probability that a discrete random variable
X takes a particular value x.

Formula: P(X=x)=f(x)
where f(x) represents the probability of X taking the value x

Example of PMF:
Consider rolling a fair 6-sided die. The random variable
X represents the outcome (1, 2, 3, 4, 5, or 6). The PMF is:
otherwise
P(X=x)={ 1/6 x∈{1,2,3,4,5,6}
          0, otherwise
​

This means the probability of rolling any specific number is 1/6


2. Probability Density Function (PDF)
The PDF is used for continuous random variables (those that take an infinite number of values within an interval). It describes the likelihood of the variable falling within a
particular range, rather than at a specific value.
Formula: P(a≤X≤b)=∫abf(x)dx
where: f(x) is the probability density function.

Since the probability of a continuous variable taking an exact value is zero, we calculate probabilities over an interval.

Example of PDF:
Consider a continuous random variable
𝑋
X representing the height of students in a school (e.g., 150 cm to 200 cm). If the heights follow a normal distribution with a mean of 170 cm and some standard deviation,
the PDF is: f(x)= 1/σ2πe - (x−μ)^2/ 2σ^2
​To find the probability that a student is between 160 cm and 180 cm, we integrate the PDF over that range.

# %%
# Q2
"""
Cumulative Distribution Function (CDF)
The Cumulative Distribution Function (CDF) gives the probability that a random variable
X takes a value less than or equal to a given value
x. It is used for both discrete and continuous probability distributions.

Formula for CDF
For Discrete Variables (PMF based CDF):

F(x)=P(X≤x)= ∑  P(X=t)
            t≤x

This is the sum of all probabilities up tox.

For Continuous Variables (PDF based CDF):
F(x)=P(X≤x)=∫ f(t)dt
            −∞

This is the area under the Probability Density Function (PDF) from
−∞ to x.

Example 1: CDF for a Discrete Random Variable
Suppose X represents the result of rolling a 6-sided die. The PMF is:

P(X=x)= 1/6 ,x∈{1,2,3,4,5,6}
The CDF is:
0,    x<1
1/6   1≤x<2
2/6   2≤x<3
3/6   3≤x<4
4/6   4≤x<5
5/6   5≤x<6
1     x≥6

This means: P(X≤3)= 3/6 =0.5 (rolling 1, 2, or 3)

P(X≤6)=1 (since all possible outcomes are covered)

Example 2: CDF for a Continuous Random Variable
If X follows a normal distribution with mean
μ=0 and standard deviation
σ=1, its PDF is:
f(x)= 1/2πe-x^2/2

The CDF is:

F(x)=∫^x 1/
    −∞ 2π1e −t 2/2dt
Since we cannot integrate this easily by hand, we use numerical methods or a table.

For example, in a standard normal distribution:
P(X≤0)=0.5
P(X≤1)≈0.8413
P(X≤−1)≈0.1587

Why is CDF Used?
To find probabilities easily: Unlike PDFs, CDFs directly give cumulative probabilities.

To compare distributions: CDFs are useful in statistics for comparing different distributions.

To generate percentiles: You can find percentiles (e.g., the median is where
F(x)=0.5).

For hypothesis testing: CDFs help in statistical tests like the Kolmogorov-Smirnov test.
"""

# %%
# Q3

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

x = np.linspace(-10, 10, 1000)

pdf1 = norm.pdf(x, loc=0, scale=1)
pdf2 = norm.pdf(x, loc=0, scale=2)
pdf3 = norm.pdf(x, loc=3, scale=1)

plt.plot(x, pdf1, label="μ=0, σ=1", color="blue")
plt.plot(x, pdf2, label="μ=0, σ=2", color="red", linestyle="dashed")
plt.plot(x, pdf3, label="μ=3, σ=1", color="green", linestyle="dotted")

plt.xlabel("X")
plt.ylabel("Probability Density")
plt.title("Effect of Mean (μ) and Standard Deviation (σ) on Normal Distribution")
plt.legend()
plt.grid()
plt.show()

# %%
# Q4

""" The normal distribution is one of the most important probability distributions in statistics, data science, and real-world applications. Its importance comes from the Central Limit Theorem (CLT), which states that the sum or average of a large number of independent random variables tends to follow a normal distribution, regardless of the original distribution of the variables.

Why is the Normal Distribution Important?
Common in Nature and Real Life

Many natural phenomena (e.g., human height, IQ, blood pressure) follow a normal distribution, making it a useful model for analyzing real-world data.

Foundation for Inferential Statistics

Many statistical tests, such as t-tests, ANOVA, and regression analysis, assume data follows a normal distribution.

Central Limit Theorem (CLT)

Even if individual data points are not normally distributed, the mean of large samples from any distribution tends to be normally distributed.

Simplifies Statistical Calculations

The properties of the normal curve allow for easy probability calculations using Z-scores and percentiles.

Used in Machine Learning & Data Science

Many algorithms, like Linear Regression and Gaussian Naive Bayes, assume that data follows a normal distribution.

Real-Life Examples of Normal Distribution
Here are a few real-world examples where the normal distribution is observed:

Human Heights

If you measure the heights of a large population, most people will have an average height, with fewer very tall or very short individuals.

Example: The height of adult males in the U.S. follows a normal distribution with a mean of 5'9" (175 cm) and a standard deviation of about 3 inches (7.6 cm).

IQ Scores

IQ scores follow a normal distribution with a mean of 100 and a standard deviation of 15.

About 68% of people have IQs between 85 and 115, and about 95% have IQs between 70 and 130.

Blood Pressure Readings

Normal blood pressure readings in adults follow a bell-shaped curve, with an average systolic pressure around 120 mmHg.

Stock Market Returns

In financial modeling, daily stock returns are often assumed to be normally distributed.

While not always true, this assumption is useful for risk assessment and portfolio optimization.

Exam Scores

In large standardized exams (e.g., SAT, GRE), student scores tend to be normally distributed around the mean score.

Measurement Errors

Errors in scientific measurements (due to random fluctuations) typically follow a normal distribution. """

# %%
# Q5
"""The Bernoulli distribution is a discrete probability distribution for a random variable which takes the value 1 with probability
p
 (success) and the value 0 with probability 1 − p (failure). It is named after Swiss mathematician Jacob Bernoulli.

 Example of Bernoulli Distribution
An example of a Bernoulli distribution could be flipping a coin. If we define “heads” as success (1) and “tails” as failure (0), then if the coin is fair, we have:

Probability of heads (p) = 0.5
Probability of tails (1−p) = 0.5
Thus, the outcomes can be modeled using a Bernoulli distribution where:P(X=1)=0.5,P(X=0)=0.5

Differences
Nature of Random Variable:

Bernoulli Distribution: Models a single trial with two possible outcomes.
Binomial Distribution: Models multiple trials and counts the number of successes across those trials.
Parameters:

Bernoulli Distribution: Defined by one parameter, p.
Binomial Distribution: Defined by two parameters, n(number of trials) and p.
Outcome Range:

Bernoulli Distribution: Outcomes are limited to {0, 1}.
Binomial Distribution: Outcomes range from {0} to {n}, where n is the total number of trials. """"

# %%
# Q6

import scipy.stats as stats

mu = 50
sigma = 10
x_value = 60

probability = 1 - stats.norm.cdf(x_value, loc=mu, scale=sigma)

print(f"Probability that X > 60: {probability:.4f}")
# Out:
# Probability that X > 60: 0.1587

# %%
# Q7

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

a, b = 0, 30

x = np.linspace(a, b, 1000)
pdf_values = uniform.pdf(x, loc=a, scale=b-a)

plt.plot(x, pdf_values, label="Uniform Distribution (0 to 30 min)", color="blue")
plt.fill_between(x, pdf_values, alpha=0.3, color="blue")
plt.xlabel("Time (minutes)")
plt.ylabel("Probability Density")
plt.title("Continuous Uniform Distribution Example")
plt.legend()
plt.grid()
plt.show()

# %%
# Q8
"""
The z-score is a statistical measurement that describes a value’s relationship to the mean of a group of values, expressed in terms of standard deviations from the mean.
It indicates how many standard deviations a data point is from the mean of the distribution

Importance of the Z-Score :
The importance of the z-score lies in its ability to provide insights into how far away a particular data point is from the average within a dataset, allowing for various
 applications:

Standardization: Z-scores allow different datasets with varying scales and units to be compared on a common scale, facilitating meaningful comparisons.

Identifying Outliers: By determining how extreme a value is relative to others in a dataset, z-scores help identify outliers—data points significantly different from others.

Probability Estimation: Z-scores can be used to estimate probabilities and percentiles within normally distributed data, enabling researchers and analysts to understand
how likely certain outcomes are.

Hypothesis Testing: In statistical hypothesis testing, z-scores are used to determine whether observed results are statistically significant by comparing them against
critical values.

Applications Across Fields: Z-scores have applications in various fields such as finance (to assess investment risks), psychology (for standardized test scores),
healthcare (to evaluate clinical measurements), and quality control in manufacturing processes."""
# Out:
# '\nThe z-score is a statistical measurement that describes a value’s relationship to the mean of a group of values, expressed in terms of standard deviations from the mean.\nIt indicates how many standard deviations a data point is from the mean of the distribution\n\nImportance of the Z-Score :\nThe importance of the z-score lies in its ability to provide insights into how far away a particular data point is from the average within a dataset, allowing for various\n applications:\n\nStandardization: Z-scores allow different datasets with varying scales and units to be compared on a common scale, facilitating meaningful comparisons.\n\nIdentifying Outliers: By determining how extreme a value is relative to others in a dataset, z-scores help identify outliers—data points significantly different from others.\n\nProbability Estimation: Z-scores can be used to estimate probabilities and percentiles within normally distributed data, enabling researchers and analysts to understand \nhow lik
# ...

# %%
# Q9

"""The Central Limit Theorem (CLT) is a fundamental statistical concept that describes the behavior of the sampling distribution of the sample mean (or sum) when independent
random variables are added together. It states that, regardless of the original population’s distribution, the distribution of the sample mean will approximate a normal (Gaussian)
distribution as the sample size becomes large, provided certain conditions are met.

The Central Limit Theorem is significant for several reasons:

1. Foundation for Inferential Statistics
The CLT provides a theoretical basis for making inferences about population parameters using sample statistics. Since many statistical methods assume normality,
 the CLT ensures that we can apply these methods even when dealing with non-normal populations, as long as the sample size is sufficiently large.
2. Sampling Distribution Approximation
It allows us to approximate the sampling distribution of the sample mean with a normal distribution when
n
 is large. This approximation holds true regardless of whether the underlying population is normally distributed or not.
3. Practical Applications in Real-World Problems
In real-world scenarios where data often do not follow a perfect normal distribution (e.g., skewed or multimodal distributions), the CLT ensures that we can still use tools like
 confidence intervals and hypothesis tests effectively by relying on large enough samples.
4. Simplification of Complex Problems
By approximating non-normal distributions with a normal one through sampling, it simplifies complex probability calculations and makes them computationally feasible.
5. Key Role in Quality Control and Risk Management
In fields such as manufacturing or finance, where averages or sums of measurements are analyzed over time, understanding that these averages tend toward normality helps in setting
 thresholds for quality control or assessing risks.
6. Basis for Large Sample Theory
Many advanced statistical techniques rely on asymptotic properties derived from the CLT to justify their validity when applied to large datasets."""

# %%
# Q10

"""Assumptions of the Central Limit Theorem :
The Central Limit Theorem (CLT) is a fundamental concept in statistics that relies on several key assumptions to ensure its validity. These assumptions are crucial for applying
the theorem correctly and making accurate statistical inferences based on sample data. Here are the main assumptions:

Random Sampling: The samples must be randomly selected from the population. This ensures that every member of the population has an equal chance of being included in the sample,
which helps to create a representative sample.

Independence: The observations within the sample must be independent of each other. This means that the selection or outcome of one observation does not influence another
observation, ensuring that each sample is a true reflection of random variation.

Sample Size: The sample size should be sufficiently large for the CLT to apply. A common rule of thumb is that a sample size of 30 or more is generally considered adequate for
the CLT to hold true, although this can vary depending on the underlying distribution.

Finite Variance: The population from which samples are drawn must have a finite variance. If the population distribution has infinite variance (as seen in certain distributions
like Cauchy), then the CLT may not apply. """
